# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from sklearn.metrics import mean_squared_error
import numpy as np

# %%
#Load the dataset
df=pd.read_csv('cleaned_medal_data.csv')

# %%
df
# Out:
#            ID                                 Name Sex   Age  Height  Weight  \
# 0          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 1          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 2          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 3          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 4          17              Paavo Johannes Aaltonen   M  32.0   175.0    64.0
# ...       ...                                  ...  ..   ...     ...     ...
# 25351  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 25352  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 25353  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 25354  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 25355  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
# ...

# %%
target_column = 'Medal'
feature_columns = ['Sex', 'Age', 'Height', 'Weight', 'Team', 'Year', 'Season', 'City', 'Sport', 'Event', 'region']

# %%
# Extract features and target variable
X = df[feature_columns]
y = df[target_column]

# %%
# Convert categorical variables to numerical using one-hot encoding
X_encoded = pd.get_dummies(X)

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.5, random_state=45)

# %%
n_estimators = 100  
model = RandomForestClassifier(n_estimators=n_estimators, random_state=45)

# %%
# Train the model
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=45)

# %%
# Make predictions on the testing set
y_pred = model.predict(X_test)

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy}")
# Out:
# Model Accuracy: 0.6826786559394227

# %%
new_data_encoded = pd.get_dummies(df[feature_columns])

# %%
N_predictions = model.predict(new_data_encoded)

# %%
N_predictions.tolist()
# Out:
# ['Gold',
#  'Gold',
#  'Gold',
#  'Gold',
#  'Bronze',
#  'Gold',
#  'Bronze',
#  'Bronze',
#  'Bronze',
#  'Bronze',
#  'Silver',
#  'Gold',
#  'Gold',
#  'Gold',
#  'Silver',
#  'Gold',
#  'Gold',
#  'Gold',
#  'Gold',
#  'Bronze',
#  'Silver',
#  'Gold',
#  'Silver',
#  'Gold',
#  'Gold',
#  'Gold',
#  'Gold',
#  'Gold',
#  'Silver',
#  'Gold',
#  'Gold',
#  'Silver',
#  'Bronze',
#  'Silver',
#  'Bronze',
#  'Bronze',
#  'Bronze',
#  'Gold',
#  'Silver',
#  'Gold',
#  'Bronze',
#  'Silver',
#  'Gold',
#  'Gold',
#  'Gold',
#  'Silver',
#  'Bronze',
#  'Silver',
#  'Bronze',
#  'Gold',
#  'Bronze',
#  'Silver',
#  'Gold',
#  'Bronze',
#  'Gold',
#  'Gold',
#  'Bronze',
#  'Bronze',
#  'Silver',
#  'Bronze',
#  'Bronze',
#  'Silver',
#  'Bronze',
#  'Bronze',
#  'Silver',
#  'Gold',
#  'Gold',
#  'Silver',
#  'Bronze',
#  'Silver',
#  'Gold',
#  'Gold',
#  'Bronze',
#  'Bronze',
#  'Silver',
#  'Bronze',
#  'Bronze',
#  'Gold',
#  'Bronze',
#  'Gold',
#  'Bronze',
#  'Bronze',
# ...

# %%
predictions_with_countries = pd.DataFrame({
    'Country': df['region'],  # Replace 'Country' with the actual column name in your 'new_data' DataFrame
    'Prediction': N_predictions
})

# %%
# Convert predictions to a list
predictions_list = predictions_with_countries.values.tolist()

# %%
predictions_list
# Out:
# [['Finland', 'Gold'],
#  ['Finland', 'Gold'],
#  ['Finland', 'Gold'],
#  ['Finland', 'Gold'],
#  ['Finland', 'Bronze'],
#  ['Netherlands', 'Gold'],
#  ['Norway', 'Bronze'],
#  ['Italy', 'Bronze'],
#  ['Spain', 'Bronze'],
#  ['Azerbaijan', 'Bronze'],
#  ['Russia', 'Silver'],
#  ['Belarus', 'Gold'],
#  ['France', 'Gold'],
#  ['France', 'Gold'],
#  ['France', 'Silver'],
#  ['Cameroon', 'Gold'],
#  ['Spain', 'Gold'],
#  ['USA', 'Gold'],
#  ['Spain', 'Gold'],
#  ['Spain', 'Bronze'],
#  ['Russia', 'Silver'],
#  ['France', 'Gold'],
#  ['Hungary', 'Silver'],
#  ['Italy', 'Gold'],
#  ['Italy', 'Gold'],
#  ['Italy', 'Gold'],
#  ['Italy', 'Gold'],
#  ['Italy', 'Gold'],
#  ['Italy', 'Silver'],
#  ['Italy', 'Gold'],
#  ['Italy', 'Gold'],
#  ['Italy', 'Silver'],
#  ['Australia', 'Bronze'],
#  ['USA', 'Silver'],
#  ['USA', 'Bronze'],
#  ['Iran', 'Bronze'],
#  ['Canada', 'Bronze'],
#  ['Pakistan', 'Gold'],
#  ['Pakistan', 'Silver'],
#  ['Russia', 'Gold'],
#  ['Uzbekistan', 'Bronze'],
# ...

# %%
# Calculate root mean square error
rmse = np.sqrt(mse)
dd

# %%
print(f" Mean Square Error (MSE): {mse}")
print(f"Root Mean Square Error (RMSE): {rmse}")
# Out:
#  Mean Square Error (MSE): 0.1932481463953305
# Root Mean Square Error (RMSE): 0.43959998452608084

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[3003  634  662]
#  [ 665 3053  584]
#  [ 786  692 2599]]

# %%
# Classification Report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Bronze       0.67      0.70      0.69      4299
#         Gold       0.70      0.71      0.70      4302
#       Silver       0.68      0.64      0.66      4077
#
#     accuracy                           0.68     12678
#    macro avg       0.68      0.68      0.68     12678
# weighted avg       0.68      0.68      0.68     12678
